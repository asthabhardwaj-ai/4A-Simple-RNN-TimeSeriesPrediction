# %% [markdown]
# # Time Series Forecasting using RNN

# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

import pandas as pd

import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# ### Functions used for processing/preparing the data

# %% [markdown]
# ## Dataset -  Daily minimum temperatures in Melbourne from 1981 to 1990

# %%
dailyTemps = pd.read_csv("daily-minimum-temperatures.csv", 
                        parse_dates=[0], index_col=[0])
dailyTemps.head()
# Out:
#             Temperature
# Date
# 1981-01-01         20.7
# 1981-01-02         17.9
# 1981-01-03         18.8
# 1981-01-04         14.6
# 1981-01-05         15.8

# %%
dailyTemps.plot(figsize=(6,4))
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Based on previous 7 days minimum temperature, predict the minimum temperature after two days

# %%
def createDelayedColumns(series, times):
    cols = []
    column_index = []
    for time in times:
        cols.append(series.shift(-time))
        lag_fmt = "t+{time}" if time > 0 else "t{time}" if time < 0 else "t"
        column_index += [(lag_fmt.format(time=time), col_name)
                        for col_name in series.columns]
    df = pd.concat(cols, axis=1)
    df.columns = pd.MultiIndex.from_tuples(column_index)
    return df

def convert3D(df):
    shape = [-1] + [len(level) for level in df.columns.remove_unused_levels().levels]
    return df.values.reshape(shape)

# %%
previousDays = 7
afterDays = 2

X = createDelayedColumns(dailyTemps, 
        times=range(-previousDays+1,1)).iloc[previousDays:-afterDays]
y = createDelayedColumns(dailyTemps, 
        times=[afterDays]).iloc[previousDays:-afterDays]

print(X.head())
print(y.head())

print(X.shape)
print(y.shape)
# Out:
#                    t-6         t-5         t-4         t-3         t-2  \
#            Temperature Temperature Temperature Temperature Temperature
# Date
# 1981-01-08        17.9        18.8        14.6        15.8        15.8
# 1981-01-09        18.8        14.6        15.8        15.8        15.8
# 1981-01-10        14.6        15.8        15.8        15.8        17.4
# 1981-01-11        15.8        15.8        15.8        17.4        21.8
# 1981-01-12        15.8        15.8        17.4        21.8        20.0
#
#                    t-1           t
#            Temperature Temperature
# Date
# 1981-01-08        15.8        17.4
# 1981-01-09        17.4        21.8
# 1981-01-10        21.8        20.0
# 1981-01-11        20.0        16.2
# 1981-01-12        16.2        13.3
#                    t+2
#            Temperature
# Date
# 1981-01-08        20.0
# 1981-01-09        16.2
# 1981-01-10        13.3
# 1981-01-11        16.7
# 1981-01-12        21.5
# (3641, 7)
# (3641, 1)

# %% [markdown]
# ### Now you have X and y, slice them into training and test dataset.

# %%
train_slice = slice(None, '1988-12-28')
test_slice = slice('1989-01-01', None)

Xtrain, Ytrain = X.loc[train_slice], y.loc[train_slice]
Xtest, Ytest = X.loc[test_slice], y.loc[test_slice]

print(Xtrain.shape)
print(Xtest.shape)
# Out:
# (2911, 7)
# (728, 7)

# %% [markdown]
# ### RNN needs 3D input

# %%
Xtrain3D = convert3D(Xtrain)
Xtest3D = convert3D(Xtest)

print(Xtrain3D.shape)
print(Xtest3D.shape)
# Out:
# (2911, 7, 1)
# (728, 7, 1)

# %% [markdown]
# ## Vanilla - Simple RNN

# %%
rnnModel = keras.models.Sequential()

rnnModel.add(keras.layers.SimpleRNN(50, return_sequences=True,
                                    input_shape=(7,1)))

rnnModel.add(keras.layers.SimpleRNN(25))

rnnModel.add(keras.layers.Dense(1))

rnnModel.summary()
# Out:
# WARNING:tensorflow:From C:\Anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn (SimpleRNN)       (None, 7, 50)             2600
# _________________________________________________________________
# simple_rnn_1 (SimpleRNN)     (None, 25)                1900
# _________________________________________________________________
# dense (Dense)                (None, 1)                 26
# =================================================================
# Total params: 4,526
# Trainable params: 4,526
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Configure  the model for training, by using appropriate optimizers and regularizations
# Available optimizer: adam, rmsprop, adagrad, sgd
# loss:  objective that the model will try to minimize. 
# Available loss: categorical_crossentropy, binary_crossentropy, mean_squared_error
# metrics: List of metrics to be evaluated by the model during training and testing. 

rnnModel.compile(loss='mse', optimizer='adam', metrics=['mae'])

# %%
# train the model

history = rnnModel.fit(Xtrain3D, Ytrain, epochs = 50, batch_size=20, validation_split=0.1, verbose=1 )
# Out:
# Train on 2619 samples, validate on 292 samples
# Epoch 1/50
# 2619/2619 [==============================] - 1s 500us/sample - loss: 42.7366 - mean_absolute_error: 5.2698 - val_loss: 18.9572 - val_mean_absolute_error: 3.4405
# Epoch 2/50
# 2619/2619 [==============================] - 1s 215us/sample - loss: 19.0151 - mean_absolute_error: 3.4286 - val_loss: 12.7089 - val_mean_absolute_error: 2.8224
# Epoch 3/50
# 2619/2619 [==============================] - 1s 212us/sample - loss: 13.2819 - mean_absolute_error: 2.8170 - val_loss: 9.8935 - val_mean_absolute_error: 2.4902
# Epoch 4/50
# 2619/2619 [==============================] - 1s 224us/sample - loss: 10.7903 - mean_absolute_error: 2.5218 - val_loss: 8.9488 - val_mean_absolute_error: 2.3608
# Epoch 5/50
# 2619/2619 [==============================] - 1s 224us/sample - loss: 9.8621 - mean_absolute_error: 2.4116 - val_loss: 9.3311 - val_mean_absolute_error: 2.4148
# Epoch 6/50
# 2619/2619 [==============================] - 1s 221us/sample - loss: 9.4284 - mean_absolute_error: 2.3684 - val_loss: 8.3524 - val_mean_absolute_error: 2.2666
# Epoch 7/50
# 2619/2619 [==============================] - 1s 230us/sample - loss: 9.1415 - mean_absolute_error: 2.3419 - val_loss: 8.1082 - val_mean_absolute_error: 2.2185
# Epoch 8/50
# 2619/2619 [==============================] - 1s 236us/sample - loss: 8.9975 - mean_absolute_error: 2.3104 - val_loss: 8.4267 - val_mean_absolute_error: 2.2583
# Epoch 9/50
# 2619/2619 [==============================] - 1s 224us/sample - loss: 8.8506 - mean_absolute_error: 2.3065 - val_loss: 8.1033 - val_mean_absolute_error: 2.2199
# Epoch 10/50
# 2619/2619 [==============================] - 1s 238us/sample - loss: 8.7308 - mean_absolute_error: 2.2843 - val_loss: 8.1676 - val_mean_absolute_error: 2.2356
# Epoch 11/50
# 2619/2619 [==============================] - 1s 230us/sample - loss: 8.6734 - mean_absolute_error: 2.2863 - val_loss: 8.0860 - val_mean_absolute_error: 2.2075
# Epoch 12/50
# 2619/2619 [==============================] - 1s 224us/sample - loss: 8.6240 - mean_absolute_error: 2.2795 - val_loss: 8.1752 - val_mean_absolute_error: 2.2453
# Epoch 13/50
# 2619/2619 [==============================] - 1s 230us/sample - loss: 8.6286 - mean_absolute_error: 2.2806 - val_loss: 8.7742 - val_mean_absolute_error: 2.2947
# Epoch 14/50
# 2619/2619 [==============================] - 1s 227us/sample - loss: 8.6342 - mean_absolute_error: 2.2695 - val_loss: 8.2439 - val_mean_absolute_error: 2.2252
# Epoch 15/50
# 2619/2619 [==============================] - 1s 236us/sample - loss: 8.6233 - mean_absolute_error: 2.2765 - val_loss: 8.0590 - val_mean_absolute_error: 2.2190
# Epoch 16/50
# 2619/2619 [==============================] - 1s 242us/sample - loss: 8.5698 - mean_absolute_error: 2.2721 - val_loss: 8.0394 - val_mean_absolute_error: 2.2140
# Epoch 17/50
# 2619/2619 [==============================] - 1s 236us/sample - loss: 8.4737 - mean_absolute_error: 2.2521 - val_loss: 8.0569 - val_mean_absolute_error: 2.2150
# Epoch 18/50
# 2619/2619 [==============================] - 1s 236us/sample - loss: 8.4726 - mean_absolute_error: 2.2515 - val_loss: 7.9135 - val_mean_absolute_error: 2.1848
# Epoch 19/50
# 2619/2619 [==============================] - 1s 230us/sample - loss: 8.4096 - mean_absolute_error: 2.2467 - val_loss: 8.3150 - val_mean_absolute_error: 2.2601
# Epoch 20/50
# 2619/2619 [==============================] - 1s 230us/sample - loss: 8.4325 - mean_absolute_error: 2.2524 - val_loss: 8.0604 - val_mean_absolute_error: 2.2129
# Epoch 21/50
# 2619/2619 [==============================] - 1s 230us/sample - loss: 8.5117 - mean_absolute_error: 2.2547 - val_loss: 8.2930 - val_mean_absolute_error: 2.2606
# Epoch 22/50
# 2619/2619 [==============================] - 1s 230us/sample - loss: 8.5377 - mean_absolute_error: 2.2616 - val_loss: 8.1940 - val_mean_absolute_error: 2.2375
# Epoch 23/50
# 2619/2619 [==============================] - 1s 236us/sample - loss: 8.4900 - mean_absolute_error: 2.2656 - val_loss: 7.9925 - val_mean_absolute_error: 2.1928
# Epoch 24/50
# 2619/2619 [==============================] - 1s 262us/sample - loss: 8.4292 - mean_absolute_error: 2.2415 - val_loss: 8.2774 - val_mean_absolute_error: 2.2553
# Epoch 25/50
# 2619/2619 [==============================] - 1s 242us/sample - loss: 8.3957 - mean_absolute_error: 2.2488 - val_loss: 8.3657 - val_mean_absolute_error: 2.2741
# Epoch 26/50
# 2619/2619 [==============================] - 1s 280us/sample - loss: 8.4008 - mean_absolute_error: 2.2440 - val_loss: 8.6707 - val_mean_absolute_error: 2.3202
# Epoch 27/50
# 2619/2619 [==============================] - 1s 268us/sample - loss: 8.4453 - mean_absolute_error: 2.2568 - val_loss: 8.2466 - val_mean_absolute_error: 2.2486
# Epoch 28/50
# 2619/2619 [==============================] - 1s 244us/sample - loss: 8.3608 - mean_absolute_error: 2.2381 - val_loss: 8.1135 - val_mean_absolute_error: 2.1921
# Epoch 29/50
# 2619/2619 [==============================] - 1s 236us/sample - loss: 8.3048 - mean_absolute_error: 2.2301 - val_loss: 8.9299 - val_mean_absolute_error: 2.3491
# Epoch 30/50
# 2619/2619 [==============================] - 1s 248us/sample - loss: 8.3539 - mean_absolute_error: 2.2463 - val_loss: 8.0801 - val_mean_absolute_error: 2.2131
# Epoch 31/50
# 2619/2619 [==============================] - 1s 244us/sample - loss: 8.2568 - mean_absolute_error: 2.2208 - val_loss: 8.0509 - val_mean_absolute_error: 2.2032
# Epoch 32/50
# 2619/2619 [==============================] - 1s 248us/sample - loss: 8.2767 - mean_absolute_error: 2.2334 - val_loss: 8.0485 - val_mean_absolute_error: 2.1906
# Epoch 33/50
# 2619/2619 [==============================] - 1s 236us/sample - loss: 8.2646 - mean_absolute_error: 2.2252 - val_loss: 8.0904 - val_mean_absolute_error: 2.2178
# Epoch 34/50
# 2619/2619 [==============================] - 1s 274us/sample - loss: 8.3034 - mean_absolute_error: 2.2332 - val_loss: 8.1522 - val_mean_absolute_error: 2.2304
# Epoch 35/50
# 2619/2619 [==============================] - 1s 288us/sample - loss: 8.2471 - mean_absolute_error: 2.2222 - val_loss: 8.0498 - val_mean_absolute_error: 2.2011
# Epoch 36/50
# 2619/2619 [==============================] - 1s 268us/sample - loss: 8.2674 - mean_absolute_error: 2.2283 - val_loss: 8.1595 - val_mean_absolute_error: 2.2305
# Epoch 37/50
# 2619/2619 [==============================] - 1s 268us/sample - loss: 8.2243 - mean_absolute_error: 2.2154 - val_loss: 8.1294 - val_mean_absolute_error: 2.2258
# Epoch 38/50
# 2619/2619 [==============================] - 1s 242us/sample - loss: 8.1866 - mean_absolute_error: 2.2209 - val_loss: 8.3997 - val_mean_absolute_error: 2.2698
# Epoch 39/50
# 2619/2619 [==============================] - 1s 262us/sample - loss: 8.2032 - mean_absolute_error: 2.2227 - val_loss: 8.1125 - val_mean_absolute_error: 2.2202
# Epoch 40/50
# 2619/2619 [==============================] - 1s 262us/sample - loss: 8.1148 - mean_absolute_error: 2.2167 - val_loss: 8.2499 - val_mean_absolute_error: 2.2567
# Epoch 41/50
# 2619/2619 [==============================] - 1s 306us/sample - loss: 8.1948 - mean_absolute_error: 2.2247 - val_loss: 8.1547 - val_mean_absolute_error: 2.2245
# Epoch 42/50
# 2619/2619 [==============================] - 1s 256us/sample - loss: 8.1458 - mean_absolute_error: 2.2140 - val_loss: 8.4006 - val_mean_absolute_error: 2.2760
# Epoch 43/50
# 2619/2619 [==============================] - 1s 236us/sample - loss: 8.2190 - mean_absolute_error: 2.2269 - val_loss: 8.2765 - val_mean_absolute_error: 2.2661
# Epoch 44/50
# 2619/2619 [==============================] - 1s 230us/sample - loss: 8.0900 - mean_absolute_error: 2.2064 - val_loss: 8.3325 - val_mean_absolute_error: 2.2704
# Epoch 45/50
# 2619/2619 [==============================] - 1s 236us/sample - loss: 8.0613 - mean_absolute_error: 2.2065 - val_loss: 8.2296 - val_mean_absolute_error: 2.2427
# Epoch 46/50
# 2619/2619 [==============================] - 1s 230us/sample - loss: 8.0782 - mean_absolute_error: 2.2070 - val_loss: 8.2689 - val_mean_absolute_error: 2.2608
# Epoch 47/50
# 2619/2619 [==============================] - 1s 230us/sample - loss: 8.0958 - mean_absolute_error: 2.2110 - val_loss: 8.3243 - val_mean_absolute_error: 2.2879
# Epoch 48/50
# 2619/2619 [==============================] - 1s 232us/sample - loss: 7.9936 - mean_absolute_error: 2.1951 - val_loss: 8.4282 - val_mean_absolute_error: 2.2682
# Epoch 49/50
# 2619/2619 [==============================] - 1s 248us/sample - loss: 8.0457 - mean_absolute_error: 2.2123 - val_loss: 8.2855 - val_mean_absolute_error: 2.2547
# Epoch 50/50
# 2619/2619 [==============================] - 1s 274us/sample - loss: 7.9483 - mean_absolute_error: 2.1942 - val_loss: 8.4841 - val_mean_absolute_error: 2.2994

# %%
# plotting training and validation loss

loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, color='red', label='Training loss')
plt.plot(epochs, val_loss, color='green', label='Validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
testResult = rnnModel.evaluate(Xtest3D, Ytest)
print(testResult)
# Out:
# 728/728 [==============================] - 0s 86us/sample - loss: 7.0122 - mean_absolute_error: 2.0661
# [7.01219538803939, 2.066066]

# %%
rnnModel.predict(Xtest3D)
# Out:
# array([[14.0329   ],
#        [14.912584 ],
#        [15.469818 ],
#        [15.476652 ],
#        [13.231074 ],
#        [12.616576 ],
#        [13.246525 ],
#        [13.804676 ],
#        [14.245089 ],
#        [13.22929  ],
#        [13.04735  ],
#        [14.211578 ],
#        [14.313802 ],
#        [14.712904 ],
#        [14.652284 ],
#        [15.095653 ],
#        [14.87055  ],
#        [13.777441 ],
#        [15.555595 ],
#        [16.404785 ],
#        [15.080539 ],
#        [15.636372 ],
#        [14.344925 ],
#        [14.175928 ],
#        [14.8556595],
#        [14.725327 ],
#        [15.287408 ],
#        [16.200489 ],
#        [16.457422 ],
#        [16.140526 ],
#        [16.400013 ],
#        [16.518476 ],
#        [16.001904 ],
#        [16.418615 ],
#        [15.69806  ],
#        [15.22122  ],
#        [15.0485735],
#        [15.636007 ],
#        [15.910372 ],
#        [15.481656 ],
#        [15.5163355],
#        [16.35365  ],
#        [16.234688 ],
#        [16.482508 ],
#        [16.265219 ],
#        [16.52852  ],
#        [16.584461 ],
#        [16.61318  ],
#        [16.63799  ],
#        [16.02028  ],
#        [16.123388 ],
#        [16.538914 ],
#        [15.902644 ],
#        [15.103722 ],
#        [15.678904 ],
#        [15.413566 ],
#        [13.816437 ],
#        [15.66978  ],
#        [15.820454 ],
#        [16.585508 ],
#        [16.619026 ],
#        [16.599363 ],
#        [16.619287 ],
#        [16.638618 ],
#        [16.577282 ],
#        [16.606722 ],
#        [16.6396   ],
#        [16.642473 ],
#        [16.550629 ],
#        [16.54755  ],
#        [16.59183  ],
#        [14.402203 ],
#        [16.10319  ],
#        [15.870628 ],
#        [15.938492 ],
#        [14.334749 ],
#        [14.185711 ],
#        [14.461338 ],
#        [14.884201 ],
#        [15.251277 ],
#        [14.940017 ],
#        [15.636912 ],
#        [14.765691 ],
#        [15.478274 ],
#        [13.527365 ],
#        [12.65306  ],
#        [12.782818 ],
#        [11.004497 ],
#        [10.9141865],
#        [12.034239 ],
#        [10.235938 ],
#        [13.060381 ],
#        [13.47334  ],
#        [13.584581 ],
#        [15.249594 ],
#        [13.626133 ],
#        [14.788072 ],
#        [13.8855915],
#        [14.679897 ],
#        [14.400391 ],
#        [14.473904 ],
#        [14.478931 ],
#        [14.262114 ],
#        [14.409395 ],
#        [12.22523  ],
#        [13.357118 ],
#        [12.401268 ],
#        [12.402388 ],
#        [10.8604145],
#        [11.102419 ],
#        [10.932975 ],
#        [ 9.88993  ],
#        [ 9.4711685],
#        [ 8.879368 ],
#        [ 8.751307 ],
#        [ 8.649672 ],
#        [10.388229 ],
#        [12.248823 ],
#        [12.292917 ],
#        [12.852775 ],
#        [14.489942 ],
#        [14.61936  ],
#        [14.069958 ],
#        [14.882801 ],
#        [13.475489 ],
#        [12.082683 ],
#        [12.77866  ],
#        [11.643768 ],
#        [10.661729 ],
#        [12.391203 ],
#        [10.812231 ],
#        [11.801666 ],
#        [12.232222 ],
#        [12.381642 ],
#        [11.743114 ],
#        [10.261679 ],
#        [10.29059  ],
#        [10.629007 ],
#        [ 8.871248 ],
#        [ 9.459742 ],
#        [ 8.16028  ],
#        [ 9.553978 ],
#        [ 8.464671 ],
#        [ 9.467927 ],
#        [ 9.694036 ],
#        [ 8.731484 ],
#        [ 8.765201 ],
#        [ 9.321977 ],
#        [ 9.465555 ],
#        [ 9.935605 ],
#        [ 9.001793 ],
#        [ 3.4429924],
#        [ 5.1544337],
#        [ 5.9384427],
#        [ 8.090373 ],
#        [ 8.068616 ],
#        [ 7.3256493],
#        [ 7.4873586],
#        [ 7.8305974],
#        [ 7.832188 ],
#        [ 7.909804 ],
#        [ 8.262334 ],
#        [ 8.439447 ],
#        [ 8.18345  ],
#        [ 8.427319 ],
#        [ 8.451325 ],
#        [ 8.904551 ],
#        [ 9.036264 ],
#        [ 8.674474 ],
#        [ 8.96509  ],
#        [ 9.433077 ],
#        [ 8.994668 ],
#        [ 7.568795 ],
#        [ 7.3014665],
#        [ 7.037558 ],
#        [ 6.9683123],
#        [ 5.870624 ],
#        [ 6.077414 ],
#        [ 5.391514 ],
#        [ 5.8335667],
#        [ 6.7348623],
#        [ 6.571587 ],
#        [ 6.681825 ],
#        [ 7.1229367],
#        [ 6.612263 ],
#        [ 6.4173746],
#        [ 7.374615 ],
#        [ 8.135816 ],
#        [ 7.574771 ],
#        [ 7.7770576],
#        [ 8.154693 ],
#        [ 8.156063 ],
#        [ 7.801091 ],
#        [ 8.374848 ],
#        [ 5.627284 ],
#        [ 5.304198 ],
#        [ 5.8673244],
#        [ 7.7337766],
#        [ 7.094994 ],
#        [ 6.4898176],
#        [ 6.4749074],
#        [ 5.9440274],
#        [ 4.931547 ],
#        [ 6.99186  ],
#        [ 6.3641315],
#        [ 7.418962 ],
#        [ 6.1316237],
#        [ 6.7558475],
#        [ 6.5897765],
#        [ 7.736901 ],
#        [ 8.274413 ],
#        [ 7.8786187],
#        [ 5.6771417],
#        [ 8.574479 ],
#        [ 8.384861 ],
#        [ 8.516905 ],
#        [ 7.58398  ],
#        [ 7.7259545],
#        [ 6.9518275],
#        [ 7.6635222],
#        [ 7.23093  ],
#        [ 8.360308 ],
#        [ 8.42859  ],
#        [ 8.410646 ],
#        [ 7.3756633],
#        [ 6.4475937],
#        [ 6.840026 ],
#        [ 8.151335 ],
#        [ 7.5590615],
#        [ 6.778563 ],
#        [ 6.976352 ],
#        [ 7.1597147],
#        [ 6.8329577],
#        [ 7.8574586],
#        [ 8.347299 ],
#        [ 7.5741277],
#        [ 7.3838096],
#        [ 8.16147  ],
#        [ 6.643333 ],
#        [ 6.8060803],
#        [ 7.6239467],
#        [ 6.6697664],
#        [ 7.3120246],
#        [ 7.445887 ],
#        [ 8.2174015],
#        [ 7.3328905],
#        [ 8.066614 ],
#        [ 7.8143897],
#        [ 8.540897 ],
#        [ 6.8287907],
#        [ 8.016547 ],
#        [ 8.745847 ],
#        [ 8.439941 ],
#        [ 8.979971 ],
#        [ 8.504557 ],
#        [ 8.4221115],
#        [ 8.001284 ],
#        [ 8.2871065],
#        [ 8.374502 ],
#        [ 8.571128 ],
#        [ 8.502346 ],
#        [ 9.056717 ],
#        [ 8.586107 ],
#        [ 8.841567 ],
#        [ 9.561304 ],
#        [ 8.40085  ],
#        [ 9.064285 ],
#        [10.1594925],
#        [ 8.223689 ],
#        [ 9.094961 ],
#        [ 7.6815815],
#        [ 9.145321 ],
#        [ 9.851631 ],
#        [10.856635 ],
#        [ 8.300306 ],
#        [ 8.190062 ],
#        [ 9.541611 ],
#        [ 8.889829 ],
#        [ 8.890133 ],
#        [ 8.209327 ],
#        [ 8.375855 ],
#        [ 8.432819 ],
#        [ 9.430714 ],
#        [ 9.045093 ],
#        [ 8.867088 ],
#        [ 8.843245 ],
#        [ 9.2027025],
#        [11.099081 ],
#        [ 9.1208515],
#        [ 9.9046955],
#        [11.248205 ],
#        [ 8.608402 ],
#        [ 9.921101 ],
#        [10.947059 ],
#        [ 9.056889 ],
#        [11.649952 ],
#        [10.131708 ],
#        [12.560221 ],
#        [11.61009  ],
#        [10.214041 ],
#        [11.89786  ],
#        [10.3913965],
#        [11.176233 ],
#        [ 8.8150835],
#        [10.518917 ],
#        [10.047512 ],
#        [ 8.446419 ],
#        [11.260944 ],
#        [10.111967 ],
#        [11.22611  ],
#        [11.30201  ],
#        [12.559966 ],
#        [11.057732 ],
#        [11.20721  ],
#        [11.981457 ],
#        [11.449518 ],
#        [ 9.75202  ],
#        [11.609218 ],
#        [11.344046 ],
#        [12.799697 ],
#        [13.974497 ],
#        [11.948208 ],
#        [12.523432 ],
#        [13.220691 ],
#        [13.904201 ],
#        [14.52216  ],
#        [14.9401455],
#        [14.023022 ],
#        [14.219877 ],
#        [15.075697 ],
#        [15.691464 ],
#        [14.946938 ],
#        [15.287238 ],
#        [15.150545 ],
#        [14.71684  ],
#        [16.497242 ],
#        [14.341589 ],
#        [15.212842 ],
#        [13.92712  ],
#        [14.948723 ],
#        [14.504458 ],
#        [14.536215 ],
#        [14.387972 ],
#        [15.680021 ],
#        [15.047105 ],
#        [15.403492 ],
#        [14.975252 ],
#        [13.866823 ],
#        [14.13703  ],
#        [13.784596 ],
#        [13.385097 ],
#        [14.4577465],
#        [14.166197 ],
#        [12.765463 ],
#        [13.927261 ],
#        [13.671321 ],
#        [14.301162 ],
#        [14.219783 ],
#        [14.329264 ],
#        [14.327369 ],
#        [13.292688 ],
#        [13.580267 ],
#        [13.2220955],
#        [14.274796 ],
#        [14.004629 ],
#        [14.174868 ],
#        [13.918141 ],
#        [14.397093 ],
#        [14.565704 ],
#        [14.415142 ],
#        [15.316931 ],
#        [15.149288 ],
#        [14.930031 ],
#        [16.198837 ],
#        [16.11917  ],
#        [16.625795 ],
#        [16.52076  ],
#        [15.971352 ],
#        [16.379015 ],
#        [16.379183 ],
#        [13.814192 ],
#        [14.099018 ],
#        [13.973091 ],
#        [14.325062 ],
#        [14.445232 ],
#        [14.133192 ],
#        [14.455965 ],
#        [14.6637535],
#        [16.116991 ],
#        [14.391498 ],
#        [15.948891 ],
#        [16.326567 ],
#        [16.398878 ],
#        [14.588705 ],
#        [16.310148 ],
#        [15.86792  ],
#        [13.698511 ],
#        [14.427709 ],
#        [14.148306 ],
#        [14.688539 ],
#        [14.78883  ],
#        [14.215849 ],
#        [14.386921 ],
#        [14.862392 ],
#        [14.903114 ],
#        [15.842198 ],
#        [14.733738 ],
#        [15.159702 ],
#        [15.032564 ],
#        [15.765535 ],
#        [15.79059  ],
#        [14.989988 ],
#        [16.424936 ],
#        [13.672209 ],
#        [14.832138 ],
#        [14.816416 ],
#        [15.906967 ],
#        [16.247143 ],
#        [14.941196 ],
#        [15.318219 ],
#        [16.51817  ],
#        [16.491764 ],
#        [16.479856 ],
#        [16.531885 ],
#        [16.54174  ],
#        [16.393427 ],
#        [16.611689 ],
#        [16.627039 ],
#        [16.600323 ],
#        [16.47175  ],
#        [15.756447 ],
#        [14.080338 ],
#        [15.15873  ],
#        [14.526765 ],
#        [14.613876 ],
#        [13.974291 ],
#        [11.623742 ],
#        [12.823204 ],
#        [13.34513  ],
#        [12.305915 ],
#        [12.083676 ],
#        [13.18528  ],
#        [13.948107 ],
#        [14.224789 ],
#        [14.039962 ],
#        [14.40871  ],
#        [14.801402 ],
#        [15.493132 ],
#        [15.171897 ],
#        [16.029293 ],
#        [16.605555 ],
#        [14.153907 ],
#        [13.452303 ],
#        [14.533691 ],
#        [14.594694 ],
#        [14.7158575],
#        [14.433566 ],
#        [12.434637 ],
#        [13.662768 ],
#        [13.830915 ],
#        [14.631626 ],
#        [14.650361 ],
#        [14.163073 ],
#        [14.9366045],
#        [15.344076 ],
#        [16.428835 ],
#        [15.209335 ],
#        [16.48626  ],
#        [15.298762 ],
#        [13.241054 ],
#        [13.148504 ],
#        [13.134894 ],
#        [13.440517 ],
#        [12.746026 ],
#        [13.639963 ],
#        [13.660783 ],
#        [14.162221 ],
#        [13.7778   ],
#        [13.86817  ],
#        [13.911034 ],
#        [13.4559765],
#        [13.348089 ],
#        [11.515528 ],
#        [12.197273 ],
#        [10.075352 ],
#        [12.556583 ],
#        [11.879962 ],
#        [11.644409 ],
#        [13.305194 ],
#        [14.0831585],
#        [14.0042095],
#        [11.754604 ],
#        [ 7.4344654],
#        [ 9.556997 ],
#        [10.495108 ],
#        [ 8.61459  ],
#        [10.448479 ],
#        [10.594772 ],
#        [10.138764 ],
#        [11.642611 ],
#        [10.695531 ],
#        [11.796914 ],
#        [ 9.006407 ],
#        [11.486433 ],
#        [10.775305 ],
#        [ 8.531266 ],
#        [ 6.5376167],
#        [ 8.855274 ],
#        [ 8.526642 ],
#        [ 8.503038 ],
#        [ 8.633249 ],
#        [ 8.191008 ],
#        [ 7.677399 ],
#        [ 6.8281627],
#        [ 8.413548 ],
#        [ 8.5796995],
#        [ 8.482243 ],
#        [ 8.389199 ],
#        [ 7.896463 ],
#        [ 8.203412 ],
#        [ 8.448117 ],
#        [ 8.427409 ],
#        [ 8.296832 ],
#        [ 7.6038957],
#        [ 8.438556 ],
#        [ 8.385032 ],
#        [ 8.209228 ],
#        [ 7.932488 ],
#        [ 8.679749 ],
#        [ 8.129155 ],
#        [ 7.187812 ],
#        [ 7.6611238],
#        [ 8.510819 ],
#        [ 8.381073 ],
#        [ 8.080308 ],
#        [ 7.5831876],
#        [ 8.225765 ],
#        [ 7.9416795],
#        [ 8.577443 ],
#        [ 8.431834 ],
#        [ 9.070386 ],
#        [ 7.36237  ],
#        [ 8.277318 ],
#        [ 5.9935966],
#        [ 7.372746 ],
#        [ 7.408016 ],
#        [ 8.246533 ],
#        [ 7.684769 ],
#        [ 7.3030896],
#        [ 7.477236 ],
#        [ 7.8524814],
#        [ 7.0854783],
#        [ 7.2473817],
#        [ 8.275587 ],
#        [ 8.467364 ],
#        [ 8.87578  ],
#        [ 7.610393 ],
#        [ 6.9159226],
#        [ 7.794652 ],
#        [ 8.513256 ],
#        [ 8.508979 ],
#        [ 8.643038 ],
#        [ 8.348103 ],
#        [ 8.7853365],
#        [ 8.603386 ],
#        [10.308308 ],
#        [10.701475 ],
#        [ 8.564605 ],
#        [ 8.695346 ],
#        [ 8.595749 ],
#        [ 8.571781 ],
#        [ 8.581753 ],
#        [ 9.112891 ],
#        [ 8.471726 ],
#        [ 8.666766 ],
#        [ 7.262961 ],
#        [ 7.0664697],
#        [ 6.7691975],
#        [ 8.42234  ],
#        [ 7.9271026],
#        [ 8.292917 ],
#        [ 8.491147 ],
#        [ 8.579144 ],
#        [ 8.028845 ],
#        [ 8.245829 ],
#        [ 8.307809 ],
#        [ 7.8318806],
#        [ 7.6052012],
#        [ 8.324458 ],
#        [ 7.945703 ],
#        [ 8.347183 ],
#        [ 8.06687  ],
#        [ 8.448604 ],
#        [ 7.6063113],
#        [ 8.357549 ],
#        [ 8.27259  ],
#        [ 8.408633 ],
#        [ 8.424309 ],
#        [ 7.881493 ],
#        [ 7.9521103],
#        [ 8.191448 ],
#        [ 8.425209 ],
#        [ 7.8437343],
#        [ 4.7715235],
#        [ 7.6171417],
#        [ 8.428529 ],
#        [ 8.488584 ],
#        [ 8.541737 ],
#        [ 7.3137746],
#        [ 7.6765623],
#        [ 8.419335 ],
#        [ 8.820889 ],
#        [ 8.682705 ],
#        [ 8.47535  ],
#        [ 8.705227 ],
#        [ 5.726854 ],
#        [ 7.854208 ],
#        [ 8.692461 ],
#        [ 8.812513 ],
#        [ 9.185113 ],
#        [ 9.26033  ],
#        [ 8.118468 ],
#        [ 9.743534 ],
#        [10.038439 ],
#        [ 6.314669 ],
#        [10.254364 ],
#        [ 8.610407 ],
#        [ 9.209709 ],
#        [ 8.851473 ],
#        [ 9.3743305],
#        [ 7.7593503],
#        [10.1394415],
#        [10.769574 ],
#        [ 8.879995 ],
#        [ 7.330846 ],
#        [10.943484 ],
#        [ 8.370339 ],
#        [10.994097 ],
#        [11.086664 ],
#        [ 9.258963 ],
#        [ 8.620551 ],
#        [ 9.968963 ],
#        [10.108316 ],
#        [ 9.568895 ],
#        [11.197612 ],
#        [ 9.525658 ],
#        [11.321683 ],
#        [10.405298 ],
#        [ 9.875646 ],
#        [ 9.484476 ],
#        [ 9.568201 ],
#        [ 8.582449 ],
#        [10.366671 ],
#        [ 9.071117 ],
#        [10.857653 ],
#        [11.880965 ],
#        [11.175109 ],
#        [ 8.5511465],
#        [12.100861 ],
#        [ 9.480764 ],
#        [11.100954 ],
#        [11.374317 ],
#        [10.089174 ],
#        [10.559983 ],
#        [12.881683 ],
#        [14.264978 ],
#        [14.027242 ],
#        [14.294723 ],
#        [14.661716 ],
#        [15.67613  ],
#        [14.146269 ],
#        [14.291542 ],
#        [13.691383 ],
#        [13.908171 ],
#        [14.702126 ],
#        [14.568983 ],
#        [14.010324 ],
#        [13.589613 ],
#        [14.424546 ],
#        [13.139423 ],
#        [13.47582  ],
#        [13.179369 ],
#        [13.541435 ],
#        [13.315863 ],
#        [12.587341 ],
#        [12.003187 ],
#        [12.486401 ],
#        [11.88047  ],
#        [10.444296 ],
#        [12.013339 ],
#        [ 9.189553 ],
#        [11.567707 ],
#        [12.354549 ],
#        [12.3207035],
#        [13.122238 ],
#        [10.487619 ],
#        [13.484959 ],
#        [13.499707 ],
#        [12.950818 ],
#        [13.997447 ],
#        [13.856683 ],
#        [14.868781 ],
#        [15.035763 ],
#        [16.153769 ],
#        [16.439322 ],
#        [16.578962 ],
#        [16.10618  ],
#        [15.916614 ],
#        [14.756735 ],
#        [14.406239 ],
#        [14.177211 ],
#        [13.488383 ],
#        [13.591867 ],
#        [13.485794 ],
#        [13.83329  ],
#        [14.33705  ],
#        [14.571395 ],
#        [14.438471 ],
#        [14.943769 ],
#        [14.401661 ],
#        [14.712644 ],
#        [14.817553 ],
#        [13.350497 ],
#        [14.239281 ],
#        [13.807731 ],
#        [13.971473 ],
#        [14.33247  ],
#        [14.128752 ]], dtype=float32)
